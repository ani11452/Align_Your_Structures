# %%
import pickle
import numpy as np
import sys
from scipy.spatial.distance import jensenshannon
from scipy.stats import wasserstein_distance
sys.path.append('../../')
# out_path = 'qm9_noH_1000_kabsch_traj_interpolator_finetune_final_539_25_evalout.pkl'
# with open(out_path, 'rb') as f:
#     data = pickle.load(f)
#     print(data.keys())  # smiles
# smiles_1 = list(data.keys())
# print(len(data.keys()))  # 1000

out_path = 'drug_interpolation_evalout_evalout.pkl'  # produced by interpolation_eval_drug.py --save_name drug_interpolation_evalout
with open(out_path, 'rb') as f:
    data = pickle.load(f)
    print(data.keys())  # smiles
smiles = list(data.keys())
print(len(data.keys()))  # 1920

# %%
keys = list(data['NC(=O)[C@H]1CC(=O)N(c2ccc(OCc3ccc([N+](=O)[O-])cc3)cc2)C1'].keys())
# for each element in list keys, create a new list to load result
result = [[] for _ in range(len(keys))]
for smile in smiles:
    for key_idx in range(len(keys)):
        key = keys[key_idx]
        if key in data[smile].keys():
            result[key_idx].append(data[smile][key])

# %%
len(keys)

# %%
for i in keys:
    print(i)

# %%
new_result = []
for result_list in result:
    new_result_list = []
    for data in result_list:
        if not np.isnan(data):
            new_result_list.append(data)
    new_result.append(new_result_list)
result = new_result

# %%
import csv

header = ['List Name', 'Mean (no md)', 'Std (no md)', 'Median (no md)', 'Min (no md)', 'Max (no md)', 
          'Mean (md_960points)', 'Std (md_960points)', 'Median (md_960points)', 'Min (md_960points)', 'Max (md_960points)',
          'Mean (md_768points)', 'Std (md_768points)', 'Median (md_768points)', 'Min (md_768points)', 'Max (md_768points)',
          'Mean (md_576points)', 'Std (md_576points)', 'Median (md_576points)', 'Min (md_576points)', 'Max (md_576points)',
          'Mean (md_384points)', 'Std (md_384points)', 'Median (md_384points)', 'Min (md_384points)', 'Max (md_384points)',
            'Mean (md_192points)', 'Std (md_192points)', 'Median (md_192points)', 'Min (md_192points)', 'Max (md_192points)',
            'Mean (md_100points)', 'Std (md_100points)', 'Median (md_100points)', 'Min (md_100points)', 'Max (md_100points)',
            'Mean (md_50points)', 'Std (md_50points)', 'Median (md_50points)', 'Min (md_50points)', 'Max (md_50points)',
          ]
data_to_save = [
    ['jsd', round(np.mean(result[0]),5), round(np.std(result[0]),5), round(np.median(result[0]),5), round(np.min(result[0]),5), round(np.max(result[0]),5),
     round(np.mean(result[7]),5), round(np.std(result[7]),5), round(np.median(result[7]),5), round(np.min(result[7]),5), round(np.max(result[7]),5),
      round(np.mean(result[11]),5), round(np.std(result[11]),5), round(np.median(result[11]),5), round(np.min(result[11]),5), round(np.max(result[11]),5),
      round(np.mean(result[15]),5), round(np.std(result[15]),5), round(np.median(result[15]),5), round(np.min(result[15]),5), round(np.max(result[15]),5),
      round(np.mean(result[19]),5), round(np.std(result[19]),5), round(np.median(result[19]),5), round(np.min(result[19]),5), round(np.max(result[19]),5),
      round(np.mean(result[23]),5), round(np.std(result[23]),5), round(np.median(result[23]),5), round(np.min(result[23]),5), round(np.max(result[23]),5),
      round(np.mean(result[27]),5), round(np.std(result[27]),5), round(np.median(result[27]),5), round(np.min(result[27]),5), round(np.max(result[27]),5),
      round(np.mean(result[31]),5), round(np.std(result[31]),5), round(np.median(result[31]),5), round(np.min(result[31]),5), round(np.max(result[31]),5)],
    ['prob', round(np.mean(result[1]),5), round(np.std(result[1]),5), round(np.median(result[1]),5), round(np.min(result[1]),5), round(np.max(result[1]),5),
      round(np.mean(result[4]),5), round(np.std(result[4]),5), round(np.median(result[4]),5), round(np.min(result[4]),5), round(np.max(result[4]),5),
      round(np.mean(result[8]),5), round(np.std(result[8]),5), round(np.median(result[8]),5), round(np.min(result[8]),5), round(np.max(result[8]),5),
      round(np.mean(result[12]),5), round(np.std(result[12]),5), round(np.median(result[12]),5), round(np.min(result[12]),5), round(np.max(result[12]),5),
      round(np.mean(result[16]),5), round(np.std(result[16]),5), round(np.median(result[16]),5), round(np.min(result[16]),5), round(np.max(result[16]),5),
      round(np.mean(result[20]),5), round(np.std(result[20]),5), round(np.median(result[20]),5), round(np.min(result[20]),5), round(np.max(result[20]),5),
      round(np.mean(result[24]),5), round(np.std(result[24]),5), round(np.median(result[24]),5), round(np.min(result[24]),5), round(np.max(result[24]),5),
      round(np.mean(result[28]),5), round(np.std(result[28]),5), round(np.median(result[28]),5), round(np.min(result[28]),5), round(np.max(result[28]),5)],
    ['valid_prob', round(np.mean(result[2]),5), round(np.std(result[2]),5), round(np.median(result[2]),5), round(np.min(result[2]),5), round(np.max(result[2]),5),
      round(np.mean(result[5]),5), round(np.std(result[5]),5), round(np.median(result[5]),5), round(np.min(result[5]),5), round(np.max(result[5]),5),
      round(np.mean(result[9]),5), round(np.std(result[9]),5), round(np.median(result[9]),5), round(np.min(result[9]),5), round(np.max(result[9]),5),
      round(np.mean(result[13]),5), round(np.std(result[13]),5), round(np.median(result[13]),5), round(np.min(result[13]),5), round(np.max(result[13]),5),
      round(np.mean(result[17]),5), round(np.std(result[17]),5), round(np.median(result[17]),5), round(np.min(result[17]),5), round(np.max(result[17]),5),
      round(np.mean(result[21]),5), round(np.std(result[21]),5), round(np.median(result[21]),5), round(np.min(result[21]),5), round(np.max(result[21]),5),
      round(np.mean(result[25]),5), round(np.std(result[25]),5), round(np.median(result[25]),5), round(np.min(result[25]),5), round(np.max(result[25]),5),
      round(np.mean(result[29]),5), round(np.std(result[29]),5), round(np.median(result[29]),5), round(np.min(result[29]),5), round(np.max(result[29]),5)],
    ['valid_rate', round(np.mean(result[3]),5), round(np.std(result[3]),5), round(np.median(result[3]),5), round(np.min(result[3]),5), round(np.max(result[3]),5),
      round(np.mean(result[6]),5), round(np.std(result[6]),5), round(np.median(result[6]),5), round(np.min(result[6]),5), round(np.max(result[6]),5),
      round(np.mean(result[10]),5), round(np.std(result[10]),5), round(np.median(result[10]),5), round(np.min(result[10]),5), round(np.max(result[10]),5),
      round(np.mean(result[14]),5), round(np.std(result[14]),5), round(np.median(result[14]),5), round(np.min(result[14]),5), round(np.max(result[14]),5),
      round(np.mean(result[18]),5), round(np.std(result[18]),5), round(np.median(result[18]),5), round(np.min(result[18]),5), round(np.max(result[18]),5),
      round(np.mean(result[22]),5), round(np.std(result[22]),5), round(np.median(result[22]),5), round(np.min(result[22]),5), round(np.max(result[22]),5),
      round(np.mean(result[26]),5), round(np.std(result[26]),5), round(np.median(result[26]),5), round(np.min(result[26]),5), round(np.max(result[26]),5),
      round(np.mean(result[30]),5), round(np.std(result[30]),5), round(np.median(result[30]),5), round(np.min(result[30]),5), round(np.max(result[30]), 5)],
]

# Write to a CSV file
csv_file = f'{out_path}_interpolation_statistics.csv'
with open(csv_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(header)
    writer.writerows(data_to_save)

print(f"Statistics saved to {csv_file}")

# %%
categories = ['MSM_JSD', 'Valid path rate', 'Average path probability', 'Valid path probability']
group1 = [0.38918,0.15773,0.01635,0.02527]
group2 = [0.48457,
0.65157,
0.0022,
0.0023]
group3 = [0.52953,
0.59273,
0.00204,
0.00215]
group4 = [0.61113,
0.50794,
0.00204,
0.00209]
group5 = [0.6595,
0.44395,
0.0022,
0.0022
]
group6 = [0.76078,
0.30212,
0.00116,
0.00216
]

# %%
fig, ax = plt.subplots(figsize=(8, 5))

x = np.arange(len(categories))  # label locations
width = 0.25  # width of the bars
ax.axvline(x=1.5, color='gray', linestyle='--', linewidth=1)

from matplotlib.cm import get_cmap

cmap = get_cmap('Reds')
# Normalize the y-values for gradient coloring (optional)
colors = cmap(np.linspace(0.2, 1., 5)) 
# Plot first two categories on left y-axis
bars1 = ax.bar(x[0:2] - 0.3, [group1[0], group1[1]], width, label='Ours, 1 ns', color='blue', alpha=0.5)
bars2 = ax.bar(x[0:2] - 0.2, [group2[0], group2[1]], width, label='MD, 2.6 ns', color=colors[0], alpha=0.5)
bars3 = ax.bar(x[0:2], [group3[0], group3[1]], width, label='MD, 2.0 ns', color=colors[1], alpha=0.5)

bars4 = ax.bar(x[0:2] + 0.1, [group4[0], group4[1]], width, label='MD, 0.52 ns', color=colors[2], alpha=0.5)
bars5 = ax.bar(x[0:2] + 0.2, [group5[0], group5[1]], width, label='MD, 0.26 ns', color=colors[3], alpha=0.5)
bars6 = ax.bar(x[0:2] + 0.3, [group6[0], group6[1]], width, label='MD, 1.0 ns', color=colors[4], alpha=0.5)


ax.set_xticks(x)
ax.set_xticklabels(categories)



# Plot last two categories on right y-axis
ax2 = ax.twinx()
bars1_2 = ax2.bar(x[2:4] - 0.3, [group1[2], group1[3]], width, label='Ours, 1 ns', color='blue', alpha=0.5)
bars2_2 = ax2.bar(x[2:4] - 0.2, [group2[2], group2[3]], width, label='MD, 2.6 ns', color=colors[0], alpha=0.5)
bars3_2 = ax2.bar(x[2:4] - 0, [group3[2], group3[3]], width, label='MD, 2.0 ns', color=colors[1], alpha=0.5)
bars4_2 = ax2.bar(x[2:4] + 0.1, [group4[2], group4[3]], width, label='MD, 0.52 ns', color=colors[2], alpha=0.5)
bars5_2 = ax2.bar(x[2:4] + 0.2, [group5[2], group5[3]], width, label='MD, 0.26 ns', color=colors[3], alpha=0.5)
bars6_2 = ax2.bar(x[2:4] + 0.3, [group6[2], group6[3]], width, label='MD, 1.0 ns', color=colors[4], alpha=0.5)


# ax.set_title('QM9 Interpolation Statistics')

ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()

fig.savefig('qm9_interpolation_statistics.pdf', bbox_inches='tight')

# %%
categories = ['MSM_JSD', 'Valid path rate', 'Average path probability', 'Valid path probability']
group1 = [0.50838,
0.19587,
0.01791,
0.06423]
group2 = [0.63557,
0.45381,
0.01428,
0.01723]
group3 = [0.72242,
0.35115,
0.00884,
0.01413]
group4 = [0.85331,
0.23123,
0.00738,
0.00783]
group5 = [0.91688,
0.1244,
0.00302,
0.00381
]
group6 = [0.93981,
0.10714,
0.0029,
0.0029
]

# %%
fig, ax = plt.subplots(figsize=(8, 5))

x = np.arange(len(categories))  # label locations
width = 0.25  # width of the bars
ax.axvline(x=1.5, color='gray', linestyle='--', linewidth=1)

from matplotlib.cm import get_cmap

cmap = get_cmap('Reds')
# Normalize the y-values for gradient coloring (optional)
colors = cmap(np.linspace(0.2, 1., 5)) 
# Plot first two categories on left y-axis
bars1 = ax.bar(x[0:2] - 0.3, [group1[0], group1[1]], width, label='Ours, 1 ns', color='blue', alpha=0.5)
bars2 = ax.bar(x[0:2] - 0.2, [group2[0], group2[1]], width, label='MD, 2.6 ns', color=colors[0], alpha=0.5)
bars3 = ax.bar(x[0:2], [group3[0], group3[1]], width, label='MD, 2.0 ns', color=colors[1], alpha=0.5)
bars4 = ax.bar(x[0:2] + 0.1, [group4[0], group4[1]], width, label='MD, 0.52 ns', color=colors[2], alpha=0.5)
bars5 = ax.bar(x[0:2] + 0.2, [group5[0], group5[1]], width, label='MD, 0.26 ns', color=colors[3], alpha=0.5)
bars6 = ax.bar(x[0:2] + 0.3, [group6[0], group6[1]], width, label='MD, 1.0 ns', color=colors[4], alpha=0.5)


ax.set_xticks(x)
ax.set_xticklabels(categories)



# Plot last two categories on right y-axis
ax2 = ax.twinx()
bars1_2 = ax2.bar(x[2:4] - 0.3, [group1[2], group1[3]], width, label='Ours, 1 ns', color='blue', alpha=0.5)
bars2_2 = ax2.bar(x[2:4] - 0.2, [group2[2], group2[3]], width, label='MD, 2.6 ns', color=colors[0], alpha=0.5)
bars3_2 = ax2.bar(x[2:4] - 0, [group3[2], group3[3]], width, label='MD, 2.0 ns', color=colors[1], alpha=0.5)

bars4_2 = ax2.bar(x[2:4] + 0.1, [group4[2], group4[3]], width, label='MD, 0.52 ns', color=colors[2], alpha=0.5)
bars5_2 = ax2.bar(x[2:4] + 0.2, [group5[2], group5[3]], width, label='MD, 0.26 ns', color=colors[3], alpha=0.5)
bars6_2 = ax2.bar(x[2:4] + 0.3, [group6[2], group6[3]], width, label='MD, 1.0 ns', color=colors[4], alpha=0.5)


# ax.set_title('Drug Interpolation Statistics')

ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()
fig.savefig('drug_interpolation_statistics.pdf', bbox_inches='tight')
